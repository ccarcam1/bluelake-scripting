# %%
import lumicks.pylake as lumicks
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

file = lumicks.File("/mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/C_Trap/2019-08-20/20190820-191615 Kymograph 4.h5")

# %%
kymo = file.kymos["4"]
kymo.plot_green(vmax=16,vmin=-4,aspect='auto')
plt.clim(0.0,20000)

# %%
# Plot single row
row = 110
plt.plot(kymo.green_image[row,:],'g');

# %%
# Plot single column
col = 1
#plt.plot(kymo.green_image[:,0:col],'g');
kymo.plot_green(vmax=16,vmin=-4,aspect='auto')[:,0:col]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-320a2bce811c> in <module>
#       2 col = 1
#       3 plt.plot(kymo.green_image[:,0:col],'g');
# ----> 4 kymo.plot_green(vmax=16,vmin=-4,aspect='auto')[:,0:col]
#
# TypeError: 'NoneType' object is not subscriptable
