# %%
# Export data in Markers files to matrixes for reading in Matlab
import numpy as np
import matplotlib.pyplot as plt
from lumicks import pylake
import glob
import scipy.io as sio
import os
directory = '/mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/'
os.chdir(directory)
files = glob.glob(directory + '*Marker*.h5')
print("found {} files in folder".format(len(files)))
for file_name in files:
    print(file_name)
    file = pylake.File(file_name)
# Out:
# found 7 files in folder
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174231 Marker 1.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174323 Marker 1.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174326 Marker 2.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174333 Marker 3.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174338 Marker 4.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174348 Marker 5.h5
# /mnt/d/OneDrive - Johns Hopkins University/Ha_CCarcamo/Data/Microscopes/C_Trap/2020-02-11 klenow lambda DNA/20200211-174350 Marker 6.h5

# %%
# Make the directions I need
os.mkdir('timestamps')
os.mkdir('forceLF1x')
os.mkdir('distance1')

# %%
#  Extract the data i'm interested in

for file_name in files:
#     print(file_name)
    file = pylake.File(file_name)
#     timestamps = file.force1x.timestamps
    force1x = file.downsampled_force1.downsampled_force1x.data
#     distance1 = file.distance1
#     key = file_name[124:len(file_name)-3]
#     sio.savemat(f"{directory}timestamps/timestamps_{key}_marker.mat",{'timestamps':file.force1x.timestamps})
    
#     file = pylake.File(file_name)
    time = file["Distance"]["Distance 1"].timestamps
    timestamps = (time - time[0]) * 1e-9
#     forceLF1x = file.(downsampled_force1)(downsampled_force1x).data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-d590b6ada10b> in <module>
#       5     file = pylake.File(file_name)
#       6 #     timestamps = file.force1x.timestamps
# ----> 7     force1x = file.downsampled_force1.downsampled_force1x.data
#       8 #     distance1 = file.distance1
#       9 #     key = file_name[124:len(file_name)-3]
#
# AttributeError: 'Slice' object has no attribute 'downsampled_force1x'

# %%
#  Check file contents

print(dir(file))
print()
for thing in dir(file):
    if not thing.startswith('_'):
        print(thing)
        print('\n\t'.join([item for item in dir(thing) if not item.startswith('_')]))
# Out:
# ['SUPPORTED_FILE_FORMAT_VERSIONS', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_check_file_format', '_get_distance', '_get_downsampled_force', '_get_force', '_get_photon_count', '_get_photon_time_tags', 'blue_photon_count', 'blue_photon_time_tags', 'bluelake_version', 'description', 'distance1', 'distance2', 'downsampled_force1', 'downsampled_force1x', 'downsampled_force1y', 'downsampled_force2', 'downsampled_force2x', 'downsampled_force2y', 'downsampled_force3', 'downsampled_force3x', 'downsampled_force3y', 'downsampled_force4', 'downsampled_force4x', 'downsampled_force4y', 'experiment', 'export_time', 'fdcurves', 'force1x', 'force1y', 'force2x', 'force2y', 'force3x', 'for
# ...

# %%
# print(file_name[124:len(file_name)-3])
